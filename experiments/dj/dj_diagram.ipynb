# %%
import datajoint as dj
from experiments.dj.result_tables import FlowPriorResult
# import torch
# Out:
# [2024-08-13 08:02:48,600][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-08-13 08:02:48,607][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
schema = dj.schema("sshrinivasan_task_transfer")
dj.Diagram(schema)

# %%
schema.list_tables()
# Out:
# ['s_i_trainer_config',
#  'adapt_prior_config',
#  's_b_v_g_p_trainer_config',
#  '__s_b_v_g_p_result',
#  'm_l_p_cond_samples_config',
#  'f_p_trainer_config',
#  'f_p_samples_config',
#  '__s_i_result',
#  'alt_data_loader_config',
#  's_b_v_g_p_config',
#  'likelihood_config',
#  'adapt_prior_trainer',
#  'l_l_trainer_config',
#  'data_loader_config',
#  '__flow_prior_result',
#  '__likelihood_result',
#  '#eval_datasets',
#  'flow_prior_config',
#  's_i_config',
#  '__adapt_prior_result',
#  '__m_l_p_cond_samples',
#  '__f_p_samples',
#  '__flow_prior_eval',
#  '__s_i_eval',
#  '__s_b_v_g_p_eval']
