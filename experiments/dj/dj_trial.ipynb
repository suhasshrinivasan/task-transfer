# %%
from experiments.dj.prior_tables import FlowPriorConfig
from experiments.dj.trainer_tables import FPTrainerConfig
from experiments.dj.dataloader_tables import DataLoaderConfig
# Out:
# [2024-05-27 13:48:39,298][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-05-27 13:48:39,394][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
from experiments.dj.schema import schema

# %%
schema.list_tables()
# Out:
# ['f_p_data_loader_config',
#  'dummy_config',
#  'l_l_trainer_config',
#  'l_l_data_loader_config']

# %%
FPTrainerConfig.drop()
# Out:
# [2024-05-27 13:48:58,886][INFO]: `sshrinivasan_task_transfer`.`f_p_trainer_config` (0 tuples)
# [2024-05-27 13:48:59,536][INFO]: Dropped table `sshrinivasan_task_transfer`.`f_p_trainer_config`
# [2024-05-27 13:48:59,613][INFO]: Tables dropped. Restart kernel.

# %%
FlowPriorConfig.drop()
# Out:
# [2024-05-27 13:49:08,535][INFO]: `sshrinivasan_task_transfer`.`flow_prior_config` (0 tuples)
# [2024-05-27 13:49:09,619][INFO]: Dropped table `sshrinivasan_task_transfer`.`flow_prior_config`
# [2024-05-27 13:49:09,696][INFO]: Tables dropped. Restart kernel.

# %%
DataLoaderConfig.drop()
# Out:
# [2024-05-27 13:49:26,146][INFO]: `sshrinivasan_task_transfer`.`data_loader_config` (0 tuples)
# [2024-05-27 13:49:26,811][INFO]: Dropped table `sshrinivasan_task_transfer`.`data_loader_config`
# [2024-05-27 13:49:26,888][INFO]: Tables dropped. Restart kernel.

# %%
fp_config = FlowPriorConfig()
fp_trainer_config = FPTrainerConfig()
dl_config = DataLoaderConfig()

# %%
fp_trainer_config.insert1({
    "id": 1,
    "lr": 1.
    "weight_decay": 1.
    "n_epochs": 123
    "batch_size": 1.
    "early_stopping_threshold": 1
    "early_stopping_patience": 1
    "logging_type": "some",
    "train_prop": 0.54
    "val_prop": 0.3,
    "eval_criterion": "some",
    "eval_interval": "some",
    "eval_params": {},
}, skip_duplicates=True)

fp_config.insert1({
    id: char(32)
    ---
    dims: int
    flow_depth: int
    flow_initial_nonlin: varchar(32)    # flow direction is data -> latent
    flow_final_nonlin: varchar(32)
    flow_nonlin: varchar(32)
    flow_base_dist: varchar(32)
    affine_type: varchar(32)
})
# Out:
#   Cell In[1], line 4
#     "weight_decay": 1.
#     ^
# SyntaxError: invalid syntax

# %%
fp_config
# Out:
# *id    dims     flow_depth     flow_initial_n flow_final_non flow_nonlin    flow_base_dist affine_type
# +----+ +------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
fp_trainer_config
# Out:
# *id    lr     weight_decay   n_epochs     batch_size     early_stopping early_stopping logging_type   train_prop     val_prop     eval_criterion eval_interval  eval_param
# +----+ +----+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +--------+
#
#  (Total: 0)

# %%
dl_config
# Out:
# *id    data_fname     train_prop     val_prop
# +----+ +------------+ +------------+ +----------+
#
#  (Total: 0)
