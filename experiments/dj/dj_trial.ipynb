# %%
from experiments.dj.prior_tables import FlowPriorConfig
from experiments.dj.trainer_tables import FPTrainerConfig
from experiments.dj.dataloader_tables import DataLoaderConfig
from experiments.dj.result_tables import FlowPriorResult
# Out:
# ---------------------------------------------------------------------------
# DataJointError                            Traceback (most recent call last)
# Cell In[11], line 4
#       2 from experiments.dj.trainer_tables import FPTrainerConfig
#       3 from experiments.dj.dataloader_tables import DataLoaderConfig
# ----> 4 from experiments.dj.result_tables import FlowPriorResult
#
# File /src/project/experiments/dj/result_tables.py:15
#      10 from .schema import schema
#      11 from .trainer_tables import FPTrainerConfig
#      14 @schema
# ---> 15 class FlowPriorResult(dj.Computed):
#      16     definition = """
#      17         -> FlowPriorConfig.proj(fp_id='id')
#      18         -> FPTrainerConfig.proj(trainer_id='id')
#    (...)
#      29         model: attach@external
#      30         """
#      32     def make(self, key):
#      33         # Print the provided key
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/schemas.py:177, in Schema.__call__(self, cls, context)
#     173     raise DataJointError(
#     174         "The schema decorator should not be applied to Part tables."
#     175     )
#     176 if self.is_activated():
# --> 177     self._decorate_master(cls, context)
#     178 else:
#     179     self.declare_list.append((cls, context))
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/schemas.py:188, in Schema._decorate_master(self, cls, context)
#     182 def _decorate_master(self, cls, context):
#     183     """
#     184
#     185     :param cls: the master class to process
#     186     :param context: the class' declaration context
#     187     """
# --> 188     self._decorate_table(
#     189         cls, context=dict(context, self=cls, **{cls.__name__: cls})
#     190     )
#     191     # Process part tables
#     192     for part in ordered_dir(cls):
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/schemas.py:226, in Schema._decorate_table(self, table_class, context, assert_declared)
#     224 is_declared = instance.is_declared
#     225 if not is_declared and not assert_declared and self.create_tables:
# --> 226     instance.declare(context)
#     227     self.connection.dependencies.clear()
#     228 is_declared = is_declared or instance.is_declared
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/table.py:96, in Table.declare(self, context)
#      91 if self.connection.in_transaction:
#      92     raise DataJointError(
#      93         "Cannot declare new tables inside a transaction, "
#      94         "e.g. from inside a populate/make call"
#      95     )
# ---> 96 sql, external_stores = declare(self.full_table_name, self.definition, context)
#      97 sql = sql.format(database=self.database)
#      98 try:
#      99     # declare all external tables before declaring main table
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/declare.py:310, in declare(full_table_name, definition, context)
#     296 if len(table_name) > MAX_TABLE_NAME_LENGTH:
#     297     raise DataJointError(
#     298         "Table name `{name}` exceeds the max length of {max_length}".format(
#     299             name=table_name, max_length=MAX_TABLE_NAME_LENGTH
#     300         )
#     301     )
#     303 (
#     304     table_comment,
#     305     primary_key,
#     306     attribute_sql,
#     307     foreign_key_sql,
#     308     index_sql,
#     309     external_stores,
# --> 310 ) = prepare_declare(definition, context)
#     312 if not primary_key:
#     313     raise DataJointError("Table must have a primary key")
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/declare.py:255, in prepare_declare(definition, context)
#     253     in_key = False  # start parsing dependent attributes
#     254 elif is_foreign_key(line):
# --> 255     compile_foreign_key(
#     256         line,
#     257         context,
#     258         attributes,
#     259         primary_key if in_key else None,
#     260         attribute_sql,
#     261         foreign_key_sql,
#     262         index_sql,
#     263     )
#     264 elif re.match(r"^(unique\s+)?index\s*.*$", line, re.I):  # index
#     265     compile_index(line, index_sql)
#
# File /usr/local/lib/python3.8/dist-packages/datajoint/declare.py:174, in compile_foreign_key(line, context, attributes, primary_key, attr_sql, foreign_key_sql, index_sql)
#     172     ref = eval(result.ref_table, context)
#     173 except Exception:
# --> 174     raise DataJointError(
#     175         "Foreign key reference %s could not be resolved" % result.ref_table
#     176     )
#     178 options = [opt.upper() for opt in result.options]
#     179 for opt in options:  # check for invalid options
#
# DataJointError: Foreign key reference FlowPriorConfig.proj(fp_id='id') could not be resolved

# %%
from experiments.dj.schema import schema

# %%
schema.list_tables()
# Out:
# ['f_p_data_loader_config',
#  'f_p_trainer_config',
#  'dummy_config',
#  'l_l_trainer_config',
#  'data_loader_config',
#  '__flow_prior_result',
#  'flow_prior_config',
#  'l_l_data_loader_config']

# %%
FPTrainerConfig.drop()
# Out:
# [2024-05-29 21:39:34,022][INFO]: `sshrinivasan_task_transfer`.`f_p_trainer_config` (2 tuples)
# [2024-05-29 21:39:34,098][INFO]: `sshrinivasan_task_transfer`.`__flow_prior_result` (0 tuples)
# [2024-05-29 21:39:35,588][INFO]: Dropped table `sshrinivasan_task_transfer`.`__flow_prior_result`
# [2024-05-29 21:39:35,704][INFO]: Dropped table `sshrinivasan_task_transfer`.`f_p_trainer_config`
# [2024-05-29 21:39:35,784][INFO]: Tables dropped. Restart kernel.

# %%
FlowPriorConfig.drop()
# Out:
# [2024-05-29 21:39:36,389][INFO]: `sshrinivasan_task_transfer`.`flow_prior_config` (32 tuples)
# [2024-05-29 21:39:37,241][INFO]: Dropped table `sshrinivasan_task_transfer`.`flow_prior_config`
# [2024-05-29 21:39:37,319][INFO]: Tables dropped. Restart kernel.

# %%
DataLoaderConfig.drop()
# Out:
# [2024-05-29 21:39:38,515][INFO]: `sshrinivasan_task_transfer`.`data_loader_config` (1 tuples)
# [2024-05-29 21:39:39,425][INFO]: Dropped table `sshrinivasan_task_transfer`.`data_loader_config`
# [2024-05-29 21:39:39,503][INFO]: Tables dropped. Restart kernel.

# %%
FPRes

# %%
fp_config = FlowPriorConfig()
fp_trainer_config = FPTrainerConfig()
dl_config = DataLoaderConfig()

# %%
fp_trainer_config.insert1({
    "id": 1,
    "lr": 1.
    "weight_decay": 1.
    "n_epochs": 123
    "batch_size": 1.
    "early_stopping_threshold": 1
    "early_stopping_patience": 1
    "logging_type": "some",
    "train_prop": 0.54
    "val_prop": 0.3,
    "eval_criterion": "some",
    "eval_interval": "some",
    "eval_params": {},
}, skip_duplicates=True)

fp_config.insert1({
    id: char(32)
    ---
    dims: int
    flow_depth: int
    flow_initial_nonlin: varchar(32)    # flow direction is data -> latent
    flow_final_nonlin: varchar(32)
    flow_nonlin: varchar(32)
    flow_base_dist: varchar(32)
    affine_type: varchar(32)
})
# Out:
#   Cell In[1], line 4
#     "weight_decay": 1.
#     ^
# SyntaxError: invalid syntax

# %%
fp_config
# Out:
# *id    dims     flow_depth     flow_initial_n flow_final_non flow_nonlin    flow_base_dist affine_type
# +----+ +------+ +------------+ +------------+ +------------+ +------------+ +------------+ +------------+
#
#  (Total: 0)

# %%
fp_trainer_config
# Out:
# *id    lr     weight_decay   n_epochs     batch_size     early_stopping early_stopping logging_type   train_prop     val_prop     eval_criterion eval_interval  eval_param
# +----+ +----+ +------------+ +----------+ +------------+ +------------+ +------------+ +------------+ +------------+ +----------+ +------------+ +------------+ +--------+
#
#  (Total: 0)

# %%
dl_config
# Out:
# *id    data_fname     train_prop     val_prop
# +----+ +------------+ +------------+ +----------+
#
#  (Total: 0)
