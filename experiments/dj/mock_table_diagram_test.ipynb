# %%
import datajoint as dj

# %%
schema = dj.schema('sshrinivasan_diagram_test')
# Out:
# [2024-08-13 07:52:45,604][INFO]: Connecting sshrinivasan@134.76.19.44:3306
# [2024-08-13 07:52:46,632][INFO]: Connected sshrinivasan@134.76.19.44:3306

# %%
schema
# Out:
# Schema `sshrinivasan_diagram_test`

# %%
@schema
class Animal(dj.Manual):
    definition = """
    animal_id: int
    ---
    animal_name: varchar(30)
    """

# %%
dj.Diagram(schema)
