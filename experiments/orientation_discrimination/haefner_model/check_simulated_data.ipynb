# %%
import torch
import pickle

# %%
import configs as cfg

# %%
task1_data_fname = cfg.haefner_model_1neuron_highdelta_task1["data_fname"]

# %%
with open(task1_data_fname, "rb") as f:
    task1_data = pickle.load(f)

# %%
task2_data_fname = cfg.haefner_model_1neuron_highdelta_task2["data_fname"]
with open(task2_data_fname, "rb") as f:
    task2_data = pickle.load(f)

# %%
x1 = task1_data["x_samples"]
x2 = task2_data["x_samples"]

# %%
x1.shape, x2.shape
# Out:
# (torch.Size([10000, 1]), torch.Size([10000, 1]))

# %%
x1.mean(), x2.mean()
# Out:
# (tensor(1.0150), tensor(3.8404))

# %%
task1neuron2_datafname = cfg.haefner_model_2neuron_highdelta_task1["data_fname"]
with open(task1neuron2_datafname, "rb") as f:
    task1neuron2_data = pickle.load(f)
task2neuron2_datafname = cfg.haefner_model_2neuron_highdelta_task2["data_fname"]
with open(task2neuron2_datafname, "rb") as f:
    task2neuron2_data = pickle.load(f)
x1_2 = task1neuron2_data["x_samples"]
x2_2 = task2neuron2_data["x_samples"]
print(x1_2.mean(dim=0), x2_2.mean(dim=0))
# Out:
# tensor([3.2151, 1.0205]) tensor([1.0129, 2.6209])

# %%
task1neuron4_datafname = cfg.haefner_model_4neuron_highdelta_task1["data_fname"]
with open(task1neuron4_datafname, "rb") as f:
    task1neuron4_data = pickle.load(f)
task4neuron4_datafname = cfg.haefner_model_4neuron_highdelta_task2["data_fname"]
with open(task4neuron4_datafname, "rb") as f:
    task4neuron4_data = pickle.load(f)
x1_4 = task1neuron4_data["x_samples"]
x4_4 = task4neuron4_data["x_samples"]
print(x1_4.mean(dim=0), x4_4.mean(dim=0))
# Out:
# tensor([1.0152, 3.2552, 1.0141, 3.1416]) tensor([3.7639, 1.0260, 2.6238, 1.0154])
